# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

model = BERTopic()
topics, probabilities = model.fit_transform(docs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 from bertopic import BERTopic
#       2 from sklearn.datasets import fetch_20newsgroups
#       4 docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
#
# File /opt/anaconda3/lib/python3.8/site-packages/bertopic/__init__.py:1, in <module>
# ----> 1 from bertopic._bertopic import BERTopic
#       3 __version__ = "0.10.0"
#       5 __all__ = [
#       6     "BERTopic",
#       7 ]
#
# File /opt/anaconda3/lib/python3.8/site-packages/bertopic/_bertopic.py:22, in <module>
#      20 # Models
#      21 import hdbscan
# ---> 22 from umap import UMAP
#      23 from sklearn.feature_extraction.text import CountVectorizer
#      24 from sklearn.metrics.pairwise import cosine_similarity
#
# File /opt/anaconda3/lib/python3.8/site-packages/umap/__init__.py:2, in <module>
#       1 from warnings import warn, catch_warnings, simplefilter
# ----> 2 from .umap_ import UMAP
#       4 try:
#       5     with catch_warnings():
#
# File /opt/anaconda3/lib/python3.8/site-packages/umap/umap_.py:47, in <module>
#      40 from umap.spectral import spectral_layout
#      41 from umap.layouts import (
#      42     optimize_layout_euclidean,
#      43     optimize_layout_generic,
#      44     optimize_layout_inverse,
#      45 )
# ---> 47 from pynndescent import NNDescent
#      48 from pynndescent.distances import named_distances as pynn_named_distances
#      49 from pynndescent.sparse import sparse_named_distances as pynn_sparse_named_distances
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/__init__.py:3, in <module>
#       1 import pkg_resources
#       2 import numba
# ----> 3 from .pynndescent_ import NNDescent, PyNNDescentTransformer
#       5 # Workaround: https://github.com/numba/numba/issues/3341
#       6 if numba.config.THREADING_LAYER == "omp":
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/pynndescent_.py:16, in <module>
#      12 from scipy.sparse import csr_matrix, coo_matrix, isspmatrix_csr, vstack as sparse_vstack, issparse
#      14 import heapq
# ---> 16 import pynndescent.sparse as sparse
#      17 import pynndescent.sparse_nndescent as sparse_nnd
#      18 import pynndescent.distances as pynnd_dist
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/sparse.py:10, in <module>
#       7 import numpy as np
#       8 import numba
# ---> 10 from pynndescent.utils import norm, tau_rand
#      11 from pynndescent.distances import (
#      12     kantorovich,
#      13     jensen_shannon_divergence,
#      14     symmetric_kl_divergence,
#      15 )
#      17 locale.setlocale(locale.LC_NUMERIC, "C")
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/utils.py:9, in <module>
#       7 import numba
#       8 from numba.core import types
# ----> 9 import numba.experimental.structref as structref
#      10 import numpy as np
#      13 @numba.njit("void(i8[:], i8)", cache=True)
#      14 def seed(rng_state, seed):
#
# ModuleNotFoundError: No module named 'numba.experimental.structref'

# %%
# !pip install bertopic

# !pip install bertopic[visualization]
# Out:
# Requirement already satisfied: bertopic in /opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (0.23.1)
# Requirement already satisfied: plotly>=4.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (4.14.3)
# Requirement already satisfied: pyyaml<6.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (5.3.1)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (4.47.0)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (1.22.4)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (2.2.0)
# Requirement already satisfied: hdbscan>=0.8.28 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (0.8.28)
# Requirement already satisfied: pandas>=1.1.5 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (1.4.2)
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (1.5.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (1.1.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.8/site-packages (from plotly>=4.7.0->bertopic) (1.3.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from plotly>=4.7.0->bertopic) (1.12.0)
# Requirement already satisfied: huggingface-hub in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.7.0)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (3.6.5)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.19.3)
# Requirement already satisfied: sentencepiece in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.96)
# Requirement already satisfied: torch>=1.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (1.11.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.12.0)
# Requirement already satisfied: cython>=0.27 in /opt/anaconda3/lib/python3.8/site-packages (from hdbscan>=0.8.28->bertopic) (0.29.21)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.1.5->bertopic) (2020.1)
# Requirement already satisfied: numba>=0.49 in /opt/anaconda3/lib/python3.8/site-packages (from umap-learn>=0.5.0->bertopic) (0.50.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.7)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub->sentence-transformers>=0.4.1->bertopic) (2.24.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub->sentence-transformers>=0.4.1->bertopic) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub->sentence-transformers>=0.4.1->bertopic) (4.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.8/site-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (2022.4.24)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.8/site-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.12.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.2.0)
# Requirement already satisfied: llvmlite<0.34,>=0.33.0.dev0 in /opt/anaconda3/lib/python3.8/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.33.0+1.g022ab0f)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (49.2.0.post20200714)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub->sentence-transformers>=0.4.1->bertopic) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->huggingface-hub->sentence-transformers>=0.4.1->bertopic) (1.25.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.9->huggingface-hub->sentence-transformers>=0.4.1->bertopic) (2.4.7)
# Requirement already satisfied: bertopic[visualization] in /opt/anaconda3/lib/python3.8/site-packages (0.10.0)
#   WARNING: bertopic 0.10.0 does not provide the extra 'visualization'
# Requirement already satisfied: plotly>=4.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (4.14.3)
# Requirement already satisfied: pandas>=1.1.5 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (1.4.2)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (0.23.1)
# Requirement already satisfied: pyyaml<6.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (5.3.1)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (4.47.0)
# Requirement already satisfied: hdbscan>=0.8.28 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (0.8.28)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (2.2.0)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (1.22.4)
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/anaconda3/lib/python3.8/site-packages (from bertopic[visualization]) (0.5.3)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.8/site-packages (from plotly>=4.7.0->bertopic[visualization]) (1.3.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from plotly>=4.7.0->bertopic[visualization]) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.1.5->bertopic[visualization]) (2020.1)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (1.5.0)
# Requirement already satisfied: cython>=0.27 in /opt/anaconda3/lib/python3.8/site-packages (from hdbscan>=0.8.28->bertopic[visualization]) (0.29.21)
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.12.0)
# Requirement already satisfied: sentencepiece in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.1.96)
# Requirement already satisfied: torch>=1.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (1.11.0)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.6.5)
# Requirement already satisfied: huggingface-hub in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.19.3)
# Requirement already satisfied: numba>=0.49 in /opt/anaconda3/lib/python3.8/site-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.50.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/lib/python3.8/site-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.5.7)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (2.24.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.8/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (7.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.8/site-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.4.24)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.8/site-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (7.1.2)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub->sentence-transformers>=0.4.1->bertopic[visualization]) (21.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.8/site-packages (from huggingface-hub->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.12)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.12.1)
# Requirement already satisfied: llvmlite<0.34,>=0.33.0.dev0 in /opt/anaconda3/lib/python3.8/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.33.0+1.g022ab0f)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (49.2.0.post20200714)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (2.10)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.9->huggingface-hub->sentence-transformers>=0.4.1->bertopic[visualization]) (2.4.7)

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

model = BERTopic()
topics, probabilities = model.fit_transform(docs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 from bertopic import BERTopic
#       2 from sklearn.datasets import fetch_20newsgroups
#       4 docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
#
# File /opt/anaconda3/lib/python3.8/site-packages/bertopic/__init__.py:1, in <module>
# ----> 1 from bertopic._bertopic import BERTopic
#       3 __version__ = "0.10.0"
#       5 __all__ = [
#       6     "BERTopic",
#       7 ]
#
# File /opt/anaconda3/lib/python3.8/site-packages/bertopic/_bertopic.py:22, in <module>
#      20 # Models
#      21 import hdbscan
# ---> 22 from umap import UMAP
#      23 from sklearn.feature_extraction.text import CountVectorizer
#      24 from sklearn.metrics.pairwise import cosine_similarity
#
# File /opt/anaconda3/lib/python3.8/site-packages/umap/__init__.py:2, in <module>
#       1 from warnings import warn, catch_warnings, simplefilter
# ----> 2 from .umap_ import UMAP
#       4 try:
#       5     with catch_warnings():
#
# File /opt/anaconda3/lib/python3.8/site-packages/umap/umap_.py:47, in <module>
#      40 from umap.spectral import spectral_layout
#      41 from umap.layouts import (
#      42     optimize_layout_euclidean,
#      43     optimize_layout_generic,
#      44     optimize_layout_inverse,
#      45 )
# ---> 47 from pynndescent import NNDescent
#      48 from pynndescent.distances import named_distances as pynn_named_distances
#      49 from pynndescent.sparse import sparse_named_distances as pynn_sparse_named_distances
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/__init__.py:3, in <module>
#       1 import pkg_resources
#       2 import numba
# ----> 3 from .pynndescent_ import NNDescent, PyNNDescentTransformer
#       5 # Workaround: https://github.com/numba/numba/issues/3341
#       6 if numba.config.THREADING_LAYER == "omp":
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/pynndescent_.py:16, in <module>
#      12 from scipy.sparse import csr_matrix, coo_matrix, isspmatrix_csr, vstack as sparse_vstack, issparse
#      14 import heapq
# ---> 16 import pynndescent.sparse as sparse
#      17 import pynndescent.sparse_nndescent as sparse_nnd
#      18 import pynndescent.distances as pynnd_dist
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/sparse.py:10, in <module>
#       7 import numpy as np
#       8 import numba
# ---> 10 from pynndescent.utils import norm, tau_rand
#      11 from pynndescent.distances import (
#      12     kantorovich,
#      13     jensen_shannon_divergence,
#      14     symmetric_kl_divergence,
#      15 )
#      17 locale.setlocale(locale.LC_NUMERIC, "C")
#
# File /opt/anaconda3/lib/python3.8/site-packages/pynndescent/utils.py:9, in <module>
#       7 import numba
#       8 from numba.core import types
# ----> 9 import numba.experimental.structref as structref
#      10 import numpy as np
#      13 @numba.njit("void(i8[:], i8)", cache=True)
#      14 def seed(rng_state, seed):
#
# ModuleNotFoundError: No module named 'numba.experimental.structref'

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.3

# %%
# !pip install numba
# Out:
# Requirement already satisfied: numba in /opt/anaconda3/lib/python3.8/site-packages (0.50.1)
# Requirement already satisfied: llvmlite<0.34,>=0.33.0.dev0 in /opt/anaconda3/lib/python3.8/site-packages (from numba) (0.33.0+1.g022ab0f)
# Requirement already satisfied: numpy>=1.15 in /opt/anaconda3/lib/python3.8/site-packages (from numba) (1.22.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from numba) (49.2.0.post20200714)

# %%
! numba -s
# Out:
# System info:
# --------------------------------------------------------------------------------
# __Time Stamp__
# Report started (local time)                   : 2022-06-09 14:49:57.331068
# UTC start time                                : 2022-06-09 18:49:57.331078
# Running time (s)                              : 4.210513
#
# __Hardware Information__
# Machine                                       : x86_64
# CPU Name                                      : skylake
# CPU Count                                     : 8
# Number of accessible CPUs                     : ?
# List of accessible CPUs cores                 : ?
# CFS Restrictions (CPUs worth of runtime)      : None
#
# CPU Features                                  : 64bit adx aes avx avx2 bmi bmi2
#                                                 clflushopt cmov cx16 cx8 f16c fma
#                                                 fsgsbase fxsr invpcid lzcnt mmx
#                                                 movbe mpx pclmul popcnt prfchw
#                                                 rdrnd rdseed sahf sgx sse sse2
#                                                 sse3 sse4.1 sse4.2 ssse3 xsave
#                                                 xsavec xsaveopt xsaves
#
# Memory Total (MB)                             : 16384
# Memory Available (MB)                         : 3881
#
# __OS Information__
# Platform Name                                 : macOS-10.16-x86_64-i386-64bit
# Platform Release                              : 21.5.0
# OS Name                                       : Darwin
# OS Version                                    : Darwin Kernel Version 21.5.0: Tue Apr 26 21:08:22 PDT 2022; root:xnu-8020.121.3~4/RELEASE_X86_64
# OS Specific Version                           : 10.16   x86_64
# Libc Version                                  : ?
#
# __Python Information__
# Python Compiler                               : Clang 10.0.0
# Python Implementation                         : CPython
# Python Version                                : 3.8.3
# Python Locale                                 : en_US.UTF-8
#
# __LLVM Information__
# LLVM Version                                  : 9.0.1
#
# __CUDA Information__
# CUDA Device Initialized                       : False
# CUDA Driver Version                           : ?
# CUDA Detect Output:
# None
# CUDA Librairies Test Output:
# None
#
# __ROC information__
# ROC Available                                 : False
# ROC Toolchains                                : None
# HSA Agents Count                              : 0
# HSA Agents:
# None
# HSA Discrete GPUs Count                       : 0
# HSA Discrete GPUs                             : None
#
# __SVML Information__
# SVML State, config.USING_SVML                 : False
# SVML Library Loaded                           : False
# llvmlite Using SVML Patched LLVM              : True
# SVML Operational                              : False
#
# __Threading Layer Information__
# TBB Threading Layer Available                 : True
# +-->TBB imported successfully.
# OpenMP Threading Layer Available              : True
# +-->Vendor: Intel
# Workqueue Threading Layer Available           : True
# +-->Workqueue imported successfully.
#
# __Numba Environment Variable Information__
# None found.
#
# __Conda Information__
# Conda Build                                   : 3.18.11
# Conda Env                                     : 4.10.0
# Conda Platform                                : osx-64
# Conda Python Version                          : 3.8.3.final.0
# Conda Root Writable                           : True
#
# __Installed Packages__
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# aiohttp                   3.7.3                    pypi_0    pypi
# alabaster                 0.7.12                     py_0    conda-forge
# anaconda                  2020.07                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.9.12                   py38_0
# anaconda-project          0.8.4                      py_0
# applaunchservices         0.2.1                      py_0    conda-forge
# appnope                   0.1.0                 py38_1001
# appscript                 1.1.1            py38haf1e3a3_0
# argh                      0.26.2                   py38_0
# argon2-cffi               21.3.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# asn1crypto                1.3.0                    py38_1
# astroid                   2.4.2                    py38_0
# astropy                   4.0.1.post1      py38h01d97ff_1
# asttokens                 2.0.5                    pypi_0    pypi
# async-timeout             3.0.1                    pypi_0    pypi
# asyncpraw                 7.1.0                    pypi_0    pypi
# asyncprawcore             1.5.1                    pypi_0    pypi
# atomicwrites              1.4.0                      py_0
# attrs                     19.3.0                     py_0    conda-forge
# autopep8                  1.5.3                      py_0
# babel                     2.8.0                      py_0
# backcall                  0.2.0                      py_0
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.3              pyhd8ed1ab_0    conda-forge
# backports.shutil_get_terminal_size 1.0.0                    py38_2
# backports.tempfile        1.0                        py_0    conda-forge
# backports.weakref         1.0.post1       py38h32f6830_1002    conda-forge
# beautifulsoup4            4.9.1                    py38_0
# bertopic                  0.10.0                   pypi_0    pypi
# bitarray                  1.4.0            py38haf1e3a3_0
# bkcharts                  0.2                      py38_0
# blas                      1.0                         mkl
# bleach                    3.1.5                      py_0
# blinker                   1.4                        py_1    conda-forge
# blis                      0.7.7                    pypi_0    pypi
# blosc                     1.19.0               hab81aa3_0
# bokeh                     2.1.1                    py38_0
# boto                      2.49.0                   py38_0
# bottleneck                1.3.2            py38hf1fa96c_1
# brotli-python             1.0.9            py38h79c402e_2
# brotlipy                  0.7.0           py38haf1e3a3_1000
# bs4                       0.0.1                    pypi_0    pypi
# bzip2                     1.0.8                h1de35cc_0
# ca-certificates           2020.6.24                     0
# cachetools                4.2.1              pyhd8ed1ab_0    conda-forge
# catalogue                 2.0.7                    pypi_0    pypi
# certifi                   2020.6.20                py38_0
# cffi                      1.14.0           py38hc512035_1
# chardet                   3.0.4                 py38_1003    conda-forge
# click                     7.1.2                      py_0
# cloudpickle               1.5.0                      py_0
# clyent                    1.2.2                    py38_1
# colorama                  0.4.3                      py_0
# conda                     4.10.0           py38h50d1736_1    conda-forge
# conda-build               3.18.11                  py38_0
# conda-env                 2.6.0                         1
# conda-package-handling    1.7.2            py38h94c058a_0    conda-forge
# conda-verify              3.4.2                      py_1
# contextlib2               0.6.0.post1                py_0    conda-forge
# cryptography              2.9.2            py38ha12b0ac_0
# curl                      7.71.1               hb0a8c7a_1
# cycler                    0.10.0                   py38_0
# cymem                     2.0.6                    pypi_0    pypi
# cython                    0.29.21          py38hb1e8313_0
# cytoolz                   0.10.1           py38h1de35cc_0
# dash                      1.13.3                   pypi_0    pypi
# dash-core-components      1.10.1                   pypi_0    pypi
# dash-html-components      1.0.3                    pypi_0    pypi
# dash-renderer             1.5.0                    pypi_0    pypi
# dash-table                4.8.1                    pypi_0    pypi
# dask                      2.20.0                     py_0
# dask-core                 2.20.0                     py_0
# dbus                      1.13.16              h18a8e69_0
# debugpy                   1.6.0                    pypi_0    pypi
# decorator                 4.4.2                      py_0    conda-forge
# defusedxml                0.6.0                      py_0
# diff-match-patch          20200713                   py_0
# distributed               2.20.0                   py38_0
# dnspython                 2.0.0                      py_0    conda-forge
# docutils                  0.16                     py38_1
# en-core-web-lg            3.3.0                    pypi_0    pypi
# entrypoints               0.3                      py38_0
# et_xmlfile                1.0.1                   py_1001    conda-forge
# executing                 0.8.3                    pypi_0    pypi
# expat                     2.2.9                hb1e8313_2
# fastcache                 1.1.0            py38h1de35cc_0
# ffn                       0.3.5                    pypi_0    pypi
# filelock                  3.0.12                     py_0
# flake8                    3.8.3                      py_0
# flask                     1.1.2                      py_0
# flask-compress            1.9.0              pyhd8ed1ab_0    conda-forge
# freetype                  2.10.2               ha233b18_0
# fsspec                    0.7.4                      py_0
# funcy                     1.17                     pypi_0    pypi
# future                    0.18.2                   py38_1
# gensim                    4.1.2                    pypi_0    pypi
# get_terminal_size         1.0.0                h7520d66_0
# gettext                   0.19.8.1             hb0f4f8b_2
# gevent                    20.6.2           py38haf1e3a3_0
# glib                      2.65.0               hc5f4afa_0
# glob2                     0.7                        py_0    conda-forge
# gmp                       6.1.2                hb37e062_1
# gmpy2                     2.0.8            py38h6ef4df4_3
# google-auth               1.4.2                    pypi_0    pypi
# greenlet                  0.4.16           py38haf1e3a3_0
# h5py                      2.10.0           py38h3134771_0
# hdbscan                   0.8.28                   pypi_0    pypi
# hdf5                      1.10.4               hfa1e0ec_0
# heapdict                  1.0.1                      py_0    conda-forge
# html5lib                  1.1                        py_0
# huggingface-hub           0.7.0                    pypi_0    pypi
# icu                       58.2                 h0a44026_3
# idna                      2.10                       py_0
# imageio                   2.9.0                      py_0    conda-forge
# imagesize                 1.2.0                      py_0    conda-forge
# importlib-metadata        1.7.0                    py38_0
# importlib_metadata        1.7.0                         0    conda-forge
# intel-openmp              2019.4                      233
# intervaltree              3.0.2                      py_1
# ipykernel                 6.13.0                   pypi_0    pypi
# ipython                   8.4.0                    pypi_0    pypi
# ipython_genutils          0.2.0                    py38_0
# ipywidgets                7.5.1                      py_0
# isort                     4.3.21                   py38_0
# itsdangerous              1.1.0                      py_0    conda-forge
# jbig                      2.1                  h4d881f8_0
# jdcal                     1.4.1                      py_0    conda-forge
# jedi                      0.17.1                   py38_0
# jellyfish                 0.9.0                    pypi_0    pypi
# jinja2                    2.11.2                     py_0
# joblib                    1.1.0                    pypi_0    pypi
# jpeg                      9b                   he5867d9_2
# json5                     0.9.5                      py_0
# jsonschema                3.2.0                    py38_1
# jupyter                   1.0.0                    py38_7
# jupyter-client            7.3.2                    pypi_0    pypi
# jupyter-core              4.10.0                   pypi_0    pypi
# jupyter_console           6.1.0                      py_0
# jupyterlab                2.1.5                      py_0
# jupyterlab_server         1.2.0                      py_0
# keyring                   21.2.1                   py38_0
# kiwisolver                1.2.0            py38h04f5b5a_0
# krb5                      1.18.2               h75d18d8_0
# langcodes                 3.3.0                    pypi_0    pypi
# lazy-object-proxy         1.4.3            py38h1de35cc_0
# lcms2                     2.11                 h92f6f08_0
# libarchive                3.4.2                haa3ed63_0
# libcurl                   7.71.1               h8a08a2b_1
# libcxx                    10.0.0                        1
# libedit                   3.1.20191231         h1de35cc_1
# libffi                    3.3                  hb1e8313_2
# libgfortran               3.0.1                h93005f0_2
# libiconv                  1.16                 h1de35cc_0
# liblief                   0.10.1               h0a44026_0
# libllvm9                  9.0.1                h21ff451_1
# libpng                    1.6.37               ha441bb4_0
# libprotobuf               3.12.3               hab81aa3_2    conda-forge
# libsodium                 1.0.18               h1de35cc_0
# libspatialindex           1.9.3                h0a44026_0
# libssh2                   1.9.0                ha12b0ac_1
# libtiff                   4.1.0                hcb84e12_1
# libxml2                   2.9.10               h3b9e6c8_1
# libxslt                   1.1.34               h83b36ba_0
# llvm-openmp               10.0.0               h28b9765_0
# llvmlite                  0.33.0           py38ha11be7d_1
# locket                    0.2.0                    py38_1
# lxml                      4.5.2            py38h63b7cb6_0
# lz4-c                     1.9.2                h0a44026_0
# lzo                       2.10                 h1de35cc_2
# markupsafe                1.1.1            py38h1de35cc_1
# matplotlib                3.2.2                         0    conda-forge
# matplotlib-base           3.2.2            py38h5670ca0_0
# matplotlib-inline         0.1.3                    pypi_0    pypi
# mccabe                    0.6.1                    py38_1
# mistune                   0.8.4           py38h1de35cc_1001
# mkl                       2019.4                      233
# mkl-service               2.3.0            py38hfbe908c_0
# mkl_fft                   1.1.0            py38hc64f4ea_0
# mkl_random                1.1.1            py38h959d312_0
# mlxtend                   0.19.0                   pypi_0    pypi
# mock                      4.0.2                      py_0
# more-itertools            8.4.0                      py_0
# mpc                       1.1.0                h6ef4df4_1
# mpfr                      4.0.2                h9066e36_1
# mpmath                    1.1.0                    py38_0
# msgpack-python            1.0.0            py38h04f5b5a_1
# multidict                 5.1.0                    pypi_0    pypi
# multipledispatch          0.6.0                    py38_0
# murmurhash                1.0.7                    pypi_0    pypi
# mysql                     5.7.20            h0a44026_1001    conda-forge
# mysql-common              8.0.20                        1    conda-forge
# mysql-connector-python    8.0.20           py38h933ed88_0    conda-forge
# mysql-libs                8.0.20               hbf7d3a9_1    conda-forge
# navigator-updater         0.2.1                    py38_0
# nbconvert                 5.6.1                    py38_1
# nbformat                  5.0.7                      py_0
# ncurses                   6.2                  h0a44026_1
# nest-asyncio              1.5.5                    pypi_0    pypi
# networkx                  2.4                        py_1
# nltk                      3.6.5                    pypi_0    pypi
# nose                      1.3.7                 py38_1004
# notebook                  6.4.11                   pypi_0    pypi
# numba                     0.50.1           py38h959d312_1
# numexpr                   2.7.1            py38hce01a72_0
# numpy                     1.22.4                   pypi_0    pypi
# numpydoc                  1.1.0                      py_0
# oauthlib                  3.0.1                      py_0    conda-forge
# olefile                   0.46                       py_0    conda-forge
# openpyxl                  3.0.4                      py_0    conda-forge
# openssl                   1.1.1g               h1de35cc_0
# packaging                 21.3                     pypi_0    pypi
# pandas                    1.4.2                    pypi_0    pypi
# pandas-datareader         0.9.0                    pypi_0    pypi
# pandoc                    2.10                          0
# pandocfilters             1.4.2                    py38_1
# parso                     0.7.0                      py_0
# partd                     1.1.0                      py_0    conda-forge
# path                      13.1.0                   py38_0
# path.py                   12.4.0                        0
# pathlib2                  2.3.5                    py38_1
# pathtools                 0.1.2                      py_1    conda-forge
# pathy                     0.6.1                    pypi_0    pypi
# patsy                     0.5.1                    py38_0
# pcre                      8.44                 hb1e8313_0
# pep8                      1.7.1                    py38_0
# pexpect                   4.8.0                    py38_1
# pickleshare               0.7.5                 py38_1001
# pillow                    7.2.0            py38ha54b6ba_0
# pip                       20.1.1                   py38_1
# pkginfo                   1.5.0.1                  py38_0
# plotly                    4.14.3             pyh44b312d_0    conda-forge
# pluggy                    0.13.1                   py38_0    conda-forge
# ply                       3.11                     py38_0
# praw                      7.0.0                      py_0    conda-forge
# prawcore                  1.3.0              pyh9f0ad1d_0    conda-forge
# preshed                   3.0.6                    pypi_0    pypi
# prometheus_client         0.8.0                      py_0
# prompt-toolkit            3.0.29                   pypi_0    pypi
# prompt_toolkit            3.0.5                         0
# protobuf                  3.12.3           py38hc84c608_0    conda-forge
# psutil                    5.7.0            py38h1de35cc_0
# ptyprocess                0.6.0                    py38_0
# pure-eval                 0.2.2                    pypi_0    pypi
# py                        1.9.0                      py_0
# py-lief                   0.10.1           py38haf313ee_0
# pyasn1                    0.4.8                    pypi_0    pypi
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycodestyle               2.6.0                      py_0
# pycosat                   0.6.3            py38h1de35cc_1
# pycparser                 2.20                       py_2
# pycurl                    7.43.0.5         py38ha12b0ac_0
# pydantic                  1.8.2                    pypi_0    pypi
# pydocstyle                5.0.2                      py_0
# pyflakes                  2.2.0                      py_0
# pygments                  2.6.1                      py_0    conda-forge
# pyjwt                     2.0.1              pyhd8ed1ab_0    conda-forge
# pyldavis                  3.3.1                    pypi_0    pypi
# pylint                    2.5.3                    py38_0
# pymysql                   1.0.2              pyhd8ed1ab_0    conda-forge
# pynndescent               0.5.7                    pypi_0    pypi
# pyodbc                    4.0.30           py38h0a44026_0
# pyopenssl                 19.1.0                     py_1
# pyparsing                 2.4.7                      py_0
# pypdf2                    1.26.0                   pypi_0    pypi
# pyphen                    0.12.0                   pypi_0    pypi
# pyqt                      5.9.2            py38h655552a_2
# pyrsistent                0.16.0           py38h1de35cc_0
# pysocks                   1.7.1                    py38_1
# pytables                  3.6.1            py38h4727e94_0
# pytest                    5.4.3                    py38_0
# python                    3.8.3                h26836e1_2
# python-dateutil           2.8.2                    pypi_0    pypi
# python-graphviz           0.20                     pypi_0    pypi
# python-jsonrpc-server     0.3.4                      py_1
# python-language-server    0.34.1                   py38_0
# python-libarchive-c       2.9                        py_0
# python.app                2                       py38_10
# python_abi                3.8                      1_cp38    conda-forge
# pytz                      2020.1                     py_0
# pywavelets                1.1.1            py38h1de35cc_0
# pyyaml                    5.3.1            py38haf1e3a3_1
# pyzmq                     23.1.0                   pypi_0    pypi
# qdarkstyle                2.8.1                      py_0
# qt                        5.9.7                h468cd18_1
# qtawesome                 0.7.2                      py_0
# qtconsole                 4.7.5                      py_0
# qtpy                      1.9.0                      py_0    conda-forge
# readline                  8.0                  h1de35cc_0
# regex                     2022.4.24                pypi_0    pypi
# requests                  2.24.0                     py_0
# requests-oauthlib         1.3.0              pyh9f0ad1d_0    conda-forge
# retrying                  1.3.3                      py_2    conda-forge
# ripgrep                   11.0.2               he32d670_0
# rope                      0.17.0                     py_0
# rsa                       4.8                      pypi_0    pypi
# rtree                     0.9.4                    py38_1
# ruamel_yaml               0.15.87          py38haf1e3a3_1
# scikit-image              0.16.2           py38h6c726b0_0
# scikit-learn              0.23.1           py38h603561c_0
# scipy                     1.5.0            py38hbab996c_0
# seaborn                   0.10.1                     py_0    conda-forge
# send2trash                1.8.0                    pypi_0    pypi
# sentence-transformers     2.2.0                    pypi_0    pypi
# sentencepiece             0.1.96                   pypi_0    pypi
# setuptools                49.2.0                   py38_0
# simplegeneric             0.8.1                    py38_2
# singledispatch            3.4.0.3                  py38_0
# sip                       4.19.8           py38h0a44026_0
# six                       1.12.0                   pypi_0    pypi
# sklearn                   0.0                      pypi_0    pypi
# smart-open                5.2.1                    pypi_0    pypi
# snappy                    1.1.8                hb1e8313_0
# snowballstemmer           2.0.0                      py_0
# sortedcollections         1.2.1                      py_0
# sortedcontainers          2.2.2                      py_0
# soupsieve                 2.0.1                      py_0
# spacy                     3.3.1                    pypi_0    pypi
# spacy-legacy              3.0.9                    pypi_0    pypi
# spacy-loggers             1.0.2                    pypi_0    pypi
# sphinx                    3.1.2                      py_0
# sphinxcontrib             1.0                      py38_1
# sphinxcontrib-applehelp   1.0.2                      py_0    conda-forge
# sphinxcontrib-devhelp     1.0.2                      py_0    conda-forge
# sphinxcontrib-htmlhelp    1.0.3                      py_0    conda-forge
# sphinxcontrib-jsmath      1.0.1                      py_0    conda-forge
# sphinxcontrib-qthelp      1.0.3                      py_0    conda-forge
# sphinxcontrib-serializinghtml 1.1.4                      py_0    conda-forge
# sphinxcontrib-websupport  1.2.3                      py_0
# spyder                    4.1.4                    py38_0
# spyder-kernels            1.9.2                    py38_0
# sqlalchemy                1.3.18           py38haf1e3a3_0
# sqlite                    3.32.3               hffcf06c_0
# srsly                     2.4.3                    pypi_0    pypi
# stack-data                0.2.0                    pypi_0    pypi
# statsmodels               0.11.1           py38haf1e3a3_0
# sympy                     1.6.1                    py38_0
# tabulate                  0.8.9                    pypi_0    pypi
# tbb                       2020.0               h04f5b5a_0
# tblib                     1.6.0                      py_0
# terminado                 0.8.3                    py38_0
# testpath                  0.4.4                      py_0    conda-forge
# textacy                   0.12.0                   pypi_0    pypi
# textblob                  0.15.1                   pypi_0    pypi
# thinc                     8.0.17                   pypi_0    pypi
# threadpoolctl             2.1.0              pyh5ca1d4c_0    conda-forge
# tk                        8.6.10               hb0a8c7a_0    conda-forge
# tokenizers                0.12.1                   pypi_0    pypi
# toml                      0.10.1                     py_0
# toolz                     0.10.0                     py_0
# torch                     1.11.0                   pypi_0    pypi
# torchvision               0.12.0                   pypi_0    pypi
# tornado                   6.1                      pypi_0    pypi
# tqdm                      4.47.0                     py_0
# traitlets                 5.2.2.post1              pypi_0    pypi
# transformers              4.19.3                   pypi_0    pypi
# tweepy                    3.10.0             pyhd8ed1ab_0    conda-forge
# typer                     0.4.1                    pypi_0    pypi
# typing-extensions         4.2.0                    pypi_0    pypi
# ujson                     1.35             py38h1de35cc_0
# umap-learn                0.5.3                    pypi_0    pypi
# unicodecsv                0.14.1                   py38_0
# unidecode                 1.2.0              pyhd8ed1ab_0    conda-forge
# unixodbc                  2.3.7                h1de35cc_0
# update_checker            0.18.0             pyh9f0ad1d_0    conda-forge
# urllib3                   1.25.9                     py_0
# vadersentiment            3.3.2                    pypi_0    pypi
# wasabi                    0.9.1                    pypi_0    pypi
# watchdog                  0.10.3           py38haf1e3a3_0
# wcwidth                   0.2.5                      py_0
# webencodings              0.5.1                    py38_1
# websocket-client          0.57.0           py38h50d1736_4    conda-forge
# werkzeug                  1.0.1                      py_0
# wheel                     0.34.2                   py38_0    conda-forge
# widgetsnbextension        3.5.1                    py38_0    conda-forge
# wordcloud                 1.5.0                    pypi_0    pypi
# wrapt                     1.11.2           py38h1de35cc_0
# wurlitzer                 2.0.1                    py38_0
# xgboost                   1.6.1                    pypi_0    pypi
# xlrd                      1.2.0                      py_0    conda-forge
# xlsxwriter                1.2.9                      py_0
# xlwings                   0.19.5                   py38_0
# xlwt                      1.3.0                    py38_0
# xmltodict                 0.12.0                     py_0    conda-forge
# xz                        5.2.5                h1de35cc_0
# yaml                      0.2.5                haf1e3a3_0    conda-forge
# yapf                      0.30.0                     py_0
# yarl                      1.6.3                    pypi_0    pypi
# zeromq                    4.3.2                hb1e8313_2
# zict                      2.0.0                      py_0    conda-forge
# zipp                      3.1.0                      py_0
# zlib                      1.2.11               h1de35cc_3
# zope                      1.0                      py38_1
# zope.event                4.4                      py38_0
# zope.interface            4.7.1            py38h1de35cc_0
# zstd                      1.4.5                h41d2c2f_0
#
# No errors reported.
#
#
# __Warning log__
# Warning (cuda): CUDA driver library cannot be found or no CUDA enabled devices are present.
# Exception class: <class 'numba.cuda.cudadrv.error.CudaSupportError'>
# Warning (roc): Error initialising ROC: No ROC toolchains found.
# Warning (roc): No HSA Agents found, encountered exception when searching: Error at driver init:
#
# HSA is not currently supported on this platform (darwin).
# :
# --------------------------------------------------------------------------------
# If requested, please copy and paste the information between
# the dashed (----) lines, or from a given specific section as
# appropriate.
#
# =============================================================
# IMPORTANT: Please ensure that you are happy with sharing the
# contents of the information present, any information that you
# wish to keep private you should remove before sharing.
# =============================================================
