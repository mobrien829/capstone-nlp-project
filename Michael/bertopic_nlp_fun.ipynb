# %% [markdown]
# <a href="https://colab.research.google.com/github/mobrien829/capstone-nlp-project/blob/main/Michael/bertopic_nlp_fun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 58 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 9.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 88 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 4.2 MB 51.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 48.8 MB/s
# ...
#      |████████████████████████████████| 86 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 59.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 47.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 49.6 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2342114 sha256=046befe2f47ad2cb6696417cc90a95bbdf63ffd78188ad2504309f3c43314a42
# ...

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

model = BERTopic()
topics, probabilities = model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %%
model.get_topic_freq().head()
# Out:
#    Topic  Count
# 0     -1   6647
# 1      0   1821
# 2      1    594
# 3      2    525
# 4      3    465

# %%
from platform import python_version

# %%
! numba -s
# Out:
# System info:
# --------------------------------------------------------------------------------
# __Time Stamp__
# Report started (local time)                   : 2022-06-09 18:48:58.059784
# UTC start time                                : 2022-06-09 18:48:58.059792
# Running time (s)                              : 0.628312
#
# __Hardware Information__
# Machine                                       : x86_64
# CPU Name                                      : haswell
# CPU Count                                     : 2
# Number of accessible CPUs                     : 2
# List of accessible CPUs cores                 : 0 1
# CFS Restrictions (CPUs worth of runtime)      : None
#
# CPU Features                                  : 64bit aes avx avx2 bmi bmi2 cmov
#                                                 cx16 cx8 f16c fma fsgsbase fxsr
#                                                 invpcid lzcnt mmx movbe pclmul
# ...

# %%
model.get_topic(0)
# Out:
# [('game', 0.010348282356307381),
#  ('team', 0.00902599419245244),
#  ('games', 0.0071925085820377975),
#  ('he', 0.006995326824800655),
#  ('players', 0.006323821530905748),
#  ('season', 0.006230152281815143),
#  ('hockey', 0.006131341490784969),
#  ('play', 0.005785335250251286),
#  ('25', 0.005646381248274563),
#  ('year', 0.005598123458670966)]

# %%
model.save("my_model")
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/_index.py:126: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probabilities[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7ce9e1637efb> in <module>()
# ----> 1 model.visualize_distribution(probabilities[0])
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_bertopic.py in visualize_distribution(self, probabilities, min_probability, width, height)
#    1111                                                min_probability=min_probability,
#    1112                                                width=width,
# -> 1113                                                height=height)
#    1114
#    1115     def visualize_hierarchy(self,
#
# /usr/local/lib/python3.7/dist-packages/bertopic/plotting/_distribution.py in visualize_distribution(topic_model, probabilities, min_probability, width, height)
#      37     """
#      38     if len(probabilities.shape) != 1:
# ...
